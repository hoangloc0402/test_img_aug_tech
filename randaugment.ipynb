# %%
import torch
from torchvision import transforms
from efficientnet_pytorch import EfficientNet
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
from implementation.utils import *
from implementation.randaugment import RandAugment

# %% [markdown]
# ## EfficientNetB0 w/ RandAugment
# https://arxiv.org/abs/1909.13719

# %%
tsfm = [RandAugment(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])]

train_data, val_data, test_data = get_dataset(tsfm)

model = EfficientNet.from_name("efficientnet-b0", override_params={'num_classes': 101})
epochs = 30
batch_size = 128

# %%
# GPU usage: 13533MiB 
train(model, train_data, val_data, epochs, batch_size)
# Out:
# EPOCH:  0, TRAIN_LOSS: 3.73303, VAL_ACCU: 0.0553, EXE TIME:  58s
# EPOCH:  1, TRAIN_LOSS: 3.18036, VAL_ACCU: 0.0236, EXE TIME:  58s
# EPOCH:  2, TRAIN_LOSS: 3.15435, VAL_ACCU: 0.0236, EXE TIME:  57s
# EPOCH:  3, TRAIN_LOSS: 2.92374, VAL_ACCU: 0.0127, EXE TIME:  58s
# EPOCH:  4, TRAIN_LOSS: 2.25082, VAL_ACCU: 0.0063, EXE TIME:  57s
# EPOCH:  5, TRAIN_LOSS: 2.21501, VAL_ACCU: 0.0035, EXE TIME:  58s
# EPOCH:  6, TRAIN_LOSS: 1.69022, VAL_ACCU: 0.0052, EXE TIME:  56s
# EPOCH:  7, TRAIN_LOSS: 1.89082, VAL_ACCU: 0.0236, EXE TIME:  58s
# EPOCH:  8, TRAIN_LOSS: 1.98648, VAL_ACCU: 0.1498, EXE TIME:  57s
# EPOCH:  9, TRAIN_LOSS: 1.28313, VAL_ACCU: 0.2944, EXE TIME:  53s
# EPOCH: 10, TRAIN_LOSS: 1.47034, VAL_ACCU: 0.5300, EXE TIME:  63s
# EPOCH: 11, TRAIN_LOSS: 1.38279, VAL_ACCU: 0.5334, EXE TIME:  60s
# EPOCH: 12, TRAIN_LOSS: 1.00967, VAL_ACCU: 0.5962, EXE TIME:  59s
# EPOCH: 13, TRAIN_LOSS: 1.06565, VAL_ACCU: 0.5858, EXE TIME:  60s
# EPOCH: 14, TRAIN_LOSS: 1.34878, VAL_ACCU: 0.5945, EXE TIME:  58s
# EPOCH: 15, TRAIN_LOSS: 0.67557, VAL_ACCU: 0.6238, EXE TIME:  61s
# EPOCH: 16, TRAIN_LOSS: 0.53576, VAL_ACCU: 0.6325, EXE TIME:  60s
# EPOCH: 17, TRAIN_LOSS: 0.47677, VAL_ACCU: 0.6244, EXE TIME:  60s
# EPOCH: 18, TRAIN_LOSS: 0.83228, VAL_ACCU: 0.6434, EXE TIME:  56s
# EPOCH: 19, TRAIN_LOSS: 0.41296, VAL_ACCU: 0.6498, EXE TIME:  58s
# EPOCH: 20, TRAIN_LOSS: 0.43247, VAL_ACCU: 0.6452, EXE TIME:  59s
# EPOCH: 21, TRAIN_LOSS: 0.49613, VAL_ACCU: 0.6573, EXE TIME:  57s
# EPOCH: 22, TRAIN_LOSS: 0.41604, VAL_ACCU: 0.6601, EXE TIME:  56s
# EPOCH: 23, TRAIN_LOSS: 0.40838, VAL_ACCU: 0.6515, EXE TIME:  57s
# EPOCH: 24, TRAIN_LOSS: 0.33792, VAL_ACCU: 0.6930, EXE TIME:  57s
# EPOCH: 25, TRAIN_LOSS: 0.52429, VAL_ACCU: 0.6941, EXE TIME:  54s
# EPOCH: 26, TRAIN_LOSS: 0.38727, VAL_ACCU: 0.6711, EXE TIME:  57s
# EPOCH: 27, TRAIN_LOSS: 0.32688, VAL_ACCU: 0.6889, EXE TIME:  49s
# EPOCH: 28, TRAIN_LOSS: 0.28848, VAL_ACCU: 0.6832, EXE TIME:  50s
# EPOCH: 29, TRAIN_LOSS: 0.30997, VAL_ACCU: 0.6901, EXE TIME:  49s

# %%
plot_graph()

# %%
evaluate(model, test_data, print_accu=True)
# Out:
# VALIDATE ACCURACY: 70.43%
