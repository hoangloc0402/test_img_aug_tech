# %%
import torch
from torchvision import transforms
from efficientnet_pytorch import EfficientNet
from utils import *
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### EfficientNet B0 w/ Random Vertical Flip

# %%
tsfm = [transforms.RandomVerticalFlip(p=0.5),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),]

train_data, val_data, test_data = get_dataset(tsfm)

model = EfficientNet.from_name("efficientnet-b0", override_params={'num_classes': 101})
epochs = 30
batch_size = 128

# %%
# GPU usage: 13533MiB 
train(model, train_data, val_data, epochs, batch_size)
# Out:
# EPOCH:  0, TRAIN_LOSS: 3.37152, VAL_ACCU: 0.0507, EXE TIME:  41s
# EPOCH:  1, TRAIN_LOSS: 3.07609, VAL_ACCU: 0.0507, EXE TIME:  42s
# EPOCH:  2, TRAIN_LOSS: 2.45731, VAL_ACCU: 0.0507, EXE TIME:  41s
# EPOCH:  3, TRAIN_LOSS: 2.48105, VAL_ACCU: 0.0104, EXE TIME:  42s
# EPOCH:  4, TRAIN_LOSS: 2.16522, VAL_ACCU: 0.0063, EXE TIME:  41s
# EPOCH:  5, TRAIN_LOSS: 2.02442, VAL_ACCU: 0.0058, EXE TIME:  42s
# EPOCH:  6, TRAIN_LOSS: 1.80663, VAL_ACCU: 0.0063, EXE TIME:  42s
# EPOCH:  7, TRAIN_LOSS: 1.69872, VAL_ACCU: 0.0058, EXE TIME:  41s
# EPOCH:  8, TRAIN_LOSS: 0.97860, VAL_ACCU: 0.0058, EXE TIME:  41s
# EPOCH:  9, TRAIN_LOSS: 1.19477, VAL_ACCU: 0.0985, EXE TIME:  42s
# EPOCH: 10, TRAIN_LOSS: 1.21585, VAL_ACCU: 0.3606, EXE TIME:  41s
# EPOCH: 11, TRAIN_LOSS: 0.97805, VAL_ACCU: 0.5029, EXE TIME:  41s
# EPOCH: 12, TRAIN_LOSS: 0.73505, VAL_ACCU: 0.5311, EXE TIME:  42s
# EPOCH: 13, TRAIN_LOSS: 0.58090, VAL_ACCU: 0.5645, EXE TIME:  41s
# EPOCH: 14, TRAIN_LOSS: 0.60810, VAL_ACCU: 0.5674, EXE TIME:  41s
# EPOCH: 15, TRAIN_LOSS: 0.41699, VAL_ACCU: 0.5668, EXE TIME:  41s
# EPOCH: 16, TRAIN_LOSS: 0.41119, VAL_ACCU: 0.5737, EXE TIME:  41s
# EPOCH: 17, TRAIN_LOSS: 0.50155, VAL_ACCU: 0.5812, EXE TIME:  42s
# EPOCH: 18, TRAIN_LOSS: 0.48358, VAL_ACCU: 0.5697, EXE TIME:  42s
# EPOCH: 19, TRAIN_LOSS: 0.28385, VAL_ACCU: 0.5985, EXE TIME:  41s
# EPOCH: 20, TRAIN_LOSS: 0.38144, VAL_ACCU: 0.6071, EXE TIME:  41s
# EPOCH: 21, TRAIN_LOSS: 0.28629, VAL_ACCU: 0.6014, EXE TIME:  41s
# EPOCH: 22, TRAIN_LOSS: 0.30226, VAL_ACCU: 0.6020, EXE TIME:  41s
# EPOCH: 23, TRAIN_LOSS: 0.14416, VAL_ACCU: 0.6043, EXE TIME:  41s
# EPOCH: 24, TRAIN_LOSS: 0.42353, VAL_ACCU: 0.5853, EXE TIME:  41s
# EPOCH: 25, TRAIN_LOSS: 0.10260, VAL_ACCU: 0.5991, EXE TIME:  41s
# EPOCH: 26, TRAIN_LOSS: 0.11598, VAL_ACCU: 0.5858, EXE TIME:  42s
# EPOCH: 27, TRAIN_LOSS: 0.18723, VAL_ACCU: 0.6094, EXE TIME:  42s
# EPOCH: 28, TRAIN_LOSS: 0.07615, VAL_ACCU: 0.6141, EXE TIME:  41s
# EPOCH: 29, TRAIN_LOSS: 0.15081, VAL_ACCU: 0.6089, EXE TIME:  42s

# %%
plot_graph()

# %%
evaluate(model, test_data, print_accu=True)
# Out:
# VALIDATE ACCURACY: 59.37%
