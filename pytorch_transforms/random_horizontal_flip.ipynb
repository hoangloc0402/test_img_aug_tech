# %%
import torch
from torchvision import transforms
from efficientnet_pytorch import EfficientNet
from utils import *
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### EfficientNet B0 w/ Random Horizontal Flip

# %%
tsfm = [transforms.RandomHorizontalFlip(p=0.5), 
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),]
 
train_data, val_data, test_data = get_dataset(tsfm)

model = EfficientNet.from_name("efficientnet-b0", override_params={'num_classes': 101})
epochs = 30
batch_size = 128

# %%
# GPU usage: 13533MiB 
train(model, train_data, val_data, epochs, batch_size)
# Out:
# EPOCH:  0, TRAIN_LOSS: 3.91482, VAL_ACCU: 0.0461, EXE TIME:  41s
# EPOCH:  1, TRAIN_LOSS: 3.04066, VAL_ACCU: 0.0236, EXE TIME:  41s
# EPOCH:  2, TRAIN_LOSS: 2.78315, VAL_ACCU: 0.0109, EXE TIME:  41s
# EPOCH:  3, TRAIN_LOSS: 2.51289, VAL_ACCU: 0.0109, EXE TIME:  41s
# EPOCH:  4, TRAIN_LOSS: 2.58798, VAL_ACCU: 0.0052, EXE TIME:  42s
# EPOCH:  5, TRAIN_LOSS: 2.30432, VAL_ACCU: 0.0052, EXE TIME:  41s
# EPOCH:  6, TRAIN_LOSS: 1.70500, VAL_ACCU: 0.0052, EXE TIME:  42s
# EPOCH:  7, TRAIN_LOSS: 1.28918, VAL_ACCU: 0.0052, EXE TIME:  42s
# EPOCH:  8, TRAIN_LOSS: 1.36208, VAL_ACCU: 0.0086, EXE TIME:  41s
# EPOCH:  9, TRAIN_LOSS: 1.05877, VAL_ACCU: 0.1388, EXE TIME:  42s
# EPOCH: 10, TRAIN_LOSS: 0.97674, VAL_ACCU: 0.3548, EXE TIME:  41s
# EPOCH: 11, TRAIN_LOSS: 0.85658, VAL_ACCU: 0.4257, EXE TIME:  42s
# EPOCH: 12, TRAIN_LOSS: 0.53392, VAL_ACCU: 0.5806, EXE TIME:  41s
# EPOCH: 13, TRAIN_LOSS: 0.76934, VAL_ACCU: 0.5778, EXE TIME:  42s
# EPOCH: 14, TRAIN_LOSS: 0.80856, VAL_ACCU: 0.5582, EXE TIME:  41s
# EPOCH: 15, TRAIN_LOSS: 0.36580, VAL_ACCU: 0.5881, EXE TIME:  42s
# EPOCH: 16, TRAIN_LOSS: 0.26373, VAL_ACCU: 0.5611, EXE TIME:  42s
# EPOCH: 17, TRAIN_LOSS: 0.53411, VAL_ACCU: 0.5847, EXE TIME:  42s
# EPOCH: 18, TRAIN_LOSS: 0.41925, VAL_ACCU: 0.5922, EXE TIME:  42s
# EPOCH: 19, TRAIN_LOSS: 0.33110, VAL_ACCU: 0.6066, EXE TIME:  42s
# EPOCH: 20, TRAIN_LOSS: 0.26154, VAL_ACCU: 0.5858, EXE TIME:  42s
# EPOCH: 21, TRAIN_LOSS: 0.18778, VAL_ACCU: 0.5904, EXE TIME:  42s
# EPOCH: 22, TRAIN_LOSS: 0.14985, VAL_ACCU: 0.5974, EXE TIME:  42s
# EPOCH: 23, TRAIN_LOSS: 0.15929, VAL_ACCU: 0.5939, EXE TIME:  42s
# EPOCH: 24, TRAIN_LOSS: 0.18251, VAL_ACCU: 0.6158, EXE TIME:  42s
# EPOCH: 25, TRAIN_LOSS: 0.12652, VAL_ACCU: 0.5824, EXE TIME:  42s
# EPOCH: 26, TRAIN_LOSS: 0.12275, VAL_ACCU: 0.6348, EXE TIME:  42s
# EPOCH: 27, TRAIN_LOSS: 0.21279, VAL_ACCU: 0.5974, EXE TIME:  42s
# EPOCH: 28, TRAIN_LOSS: 0.14160, VAL_ACCU: 0.6250, EXE TIME:  42s
# EPOCH: 29, TRAIN_LOSS: 0.14104, VAL_ACCU: 0.6187, EXE TIME:  42s

# %%
plot_graph()

# %%
evaluate(model, test_data, print_accu=True)
# Out:
# VALIDATE ACCURACY: 62.48%
