# %%
import torch
from torchvision import transforms
from efficientnet_pytorch import EfficientNet
from utils import *
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### EfficientNet B0 w/  RandomResizedCrop

# %%
tsfm = [transforms.RandomResizedCrop(224, scale=(0.5, 0.9), ratio=(0.75, 1.33)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])]

train_data, val_data, test_data = get_dataset(tsfm)

model = EfficientNet.from_name("efficientnet-b0", override_params={'num_classes': 101})
epochs = 30
batch_size = 128

# %%
# GPU usage: 13533MiB 
train(model, train_data, val_data, epochs, batch_size)
# Out:
# EPOCH:  0, TRAIN_LOSS: 4.00758, VAL_ACCU: 0.0876, EXE TIME:  45s
# EPOCH:  1, TRAIN_LOSS: 2.96842, VAL_ACCU: 0.0294, EXE TIME:  45s
# EPOCH:  2, TRAIN_LOSS: 2.86882, VAL_ACCU: 0.0132, EXE TIME:  45s
# EPOCH:  3, TRAIN_LOSS: 2.75460, VAL_ACCU: 0.0081, EXE TIME:  45s
# EPOCH:  4, TRAIN_LOSS: 2.14698, VAL_ACCU: 0.0046, EXE TIME:  45s
# EPOCH:  5, TRAIN_LOSS: 2.55587, VAL_ACCU: 0.0046, EXE TIME:  45s
# EPOCH:  6, TRAIN_LOSS: 2.15383, VAL_ACCU: 0.0069, EXE TIME:  45s
# EPOCH:  7, TRAIN_LOSS: 1.71249, VAL_ACCU: 0.0069, EXE TIME:  45s
# EPOCH:  8, TRAIN_LOSS: 1.49108, VAL_ACCU: 0.0501, EXE TIME:  45s
# EPOCH:  9, TRAIN_LOSS: 1.88193, VAL_ACCU: 0.1768, EXE TIME:  45s
# EPOCH: 10, TRAIN_LOSS: 1.69708, VAL_ACCU: 0.3963, EXE TIME:  45s
# EPOCH: 11, TRAIN_LOSS: 0.93900, VAL_ACCU: 0.5259, EXE TIME:  46s
# EPOCH: 12, TRAIN_LOSS: 0.95094, VAL_ACCU: 0.5749, EXE TIME:  45s
# EPOCH: 13, TRAIN_LOSS: 1.06510, VAL_ACCU: 0.5881, EXE TIME:  45s
# EPOCH: 14, TRAIN_LOSS: 0.90890, VAL_ACCU: 0.6141, EXE TIME:  45s
# EPOCH: 15, TRAIN_LOSS: 0.79969, VAL_ACCU: 0.6135, EXE TIME:  45s
# EPOCH: 16, TRAIN_LOSS: 1.01488, VAL_ACCU: 0.6169, EXE TIME:  45s
# EPOCH: 17, TRAIN_LOSS: 0.58257, VAL_ACCU: 0.5939, EXE TIME:  45s
# EPOCH: 18, TRAIN_LOSS: 0.52840, VAL_ACCU: 0.6152, EXE TIME:  45s
# EPOCH: 19, TRAIN_LOSS: 0.61688, VAL_ACCU: 0.5651, EXE TIME:  45s
# EPOCH: 20, TRAIN_LOSS: 0.34546, VAL_ACCU: 0.6555, EXE TIME:  45s
# EPOCH: 21, TRAIN_LOSS: 0.46087, VAL_ACCU: 0.6296, EXE TIME:  45s
# EPOCH: 22, TRAIN_LOSS: 0.56426, VAL_ACCU: 0.6521, EXE TIME:  45s
# EPOCH: 23, TRAIN_LOSS: 0.41441, VAL_ACCU: 0.6498, EXE TIME:  46s
# EPOCH: 24, TRAIN_LOSS: 0.31074, VAL_ACCU: 0.6590, EXE TIME:  45s
# EPOCH: 25, TRAIN_LOSS: 0.41734, VAL_ACCU: 0.6849, EXE TIME:  45s
# EPOCH: 26, TRAIN_LOSS: 0.43922, VAL_ACCU: 0.6717, EXE TIME:  45s
# EPOCH: 27, TRAIN_LOSS: 0.38239, VAL_ACCU: 0.6647, EXE TIME:  45s
# EPOCH: 28, TRAIN_LOSS: 0.23250, VAL_ACCU: 0.6987, EXE TIME:  45s
# EPOCH: 29, TRAIN_LOSS: 0.23209, VAL_ACCU: 0.6861, EXE TIME:  45s

# %%
plot_graph()

# %%
evaluate(model, test_data, print_accu=True)
# Out:
# VALIDATE ACCURACY: 68.13%
