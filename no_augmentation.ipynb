# %%
import torch
from torchvision import transforms
from efficientnet_pytorch import EfficientNet
from utils import *
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### EfficientNet B0 - No Image Augmentation Technique

# %%
tsfm = [transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),]
train_data, val_data, test_data = get_dataset(tsfm)
model = EfficientNet.from_name("efficientnet-b0", override_params={'num_classes': 101})
epochs = 30
batch_size = 128

# %%
# GPU usage: 13735MiB
train(model, train_data, val_data, epochs, batch_size)
# Out:
# EPOCH:  0, TRAIN_LOSS: 3.59544, VAL_ACCU: 0.0472, EXE TIME:  41s
# EPOCH:  1, TRAIN_LOSS: 2.96728, VAL_ACCU: 0.0472, EXE TIME:  42s
# EPOCH:  2, TRAIN_LOSS: 2.71068, VAL_ACCU: 0.0058, EXE TIME:  42s
# EPOCH:  3, TRAIN_LOSS: 2.30415, VAL_ACCU: 0.0058, EXE TIME:  42s
# EPOCH:  4, TRAIN_LOSS: 1.91239, VAL_ACCU: 0.0052, EXE TIME:  42s
# EPOCH:  5, TRAIN_LOSS: 1.84474, VAL_ACCU: 0.0052, EXE TIME:  42s
# EPOCH:  6, TRAIN_LOSS: 1.18950, VAL_ACCU: 0.0052, EXE TIME:  41s
# EPOCH:  7, TRAIN_LOSS: 1.14449, VAL_ACCU: 0.0052, EXE TIME:  42s
# EPOCH:  8, TRAIN_LOSS: 0.95513, VAL_ACCU: 0.0104, EXE TIME:  42s
# EPOCH:  9, TRAIN_LOSS: 0.65909, VAL_ACCU: 0.1020, EXE TIME:  42s
# EPOCH: 10, TRAIN_LOSS: 0.56054, VAL_ACCU: 0.3001, EXE TIME:  41s
# EPOCH: 11, TRAIN_LOSS: 0.27778, VAL_ACCU: 0.4470, EXE TIME:  41s
# EPOCH: 12, TRAIN_LOSS: 0.12072, VAL_ACCU: 0.4695, EXE TIME:  41s
# EPOCH: 13, TRAIN_LOSS: 0.29239, VAL_ACCU: 0.4931, EXE TIME:  42s
# EPOCH: 14, TRAIN_LOSS: 0.18344, VAL_ACCU: 0.5109, EXE TIME:  42s
# EPOCH: 15, TRAIN_LOSS: 0.19980, VAL_ACCU: 0.5046, EXE TIME:  42s
# EPOCH: 16, TRAIN_LOSS: 0.18777, VAL_ACCU: 0.5092, EXE TIME:  42s
# EPOCH: 17, TRAIN_LOSS: 0.16459, VAL_ACCU: 0.5184, EXE TIME:  42s
# EPOCH: 18, TRAIN_LOSS: 0.29109, VAL_ACCU: 0.5346, EXE TIME:  42s
# EPOCH: 19, TRAIN_LOSS: 0.06179, VAL_ACCU: 0.5300, EXE TIME:  42s
# EPOCH: 20, TRAIN_LOSS: 0.08876, VAL_ACCU: 0.5213, EXE TIME:  42s
# EPOCH: 21, TRAIN_LOSS: 0.22036, VAL_ACCU: 0.5323, EXE TIME:  42s
# EPOCH: 22, TRAIN_LOSS: 0.09931, VAL_ACCU: 0.5311, EXE TIME:  41s
# EPOCH: 23, TRAIN_LOSS: 0.12244, VAL_ACCU: 0.5305, EXE TIME:  41s
# EPOCH: 24, TRAIN_LOSS: 0.05255, VAL_ACCU: 0.5472, EXE TIME:  42s
# EPOCH: 25, TRAIN_LOSS: 0.09410, VAL_ACCU: 0.5253, EXE TIME:  42s
# EPOCH: 26, TRAIN_LOSS: 0.04278, VAL_ACCU: 0.5369, EXE TIME:  42s
# EPOCH: 27, TRAIN_LOSS: 0.11090, VAL_ACCU: 0.5438, EXE TIME:  42s
# EPOCH: 28, TRAIN_LOSS: 0.08122, VAL_ACCU: 0.5449, EXE TIME:  42s
# EPOCH: 29, TRAIN_LOSS: 0.07555, VAL_ACCU: 0.5248, EXE TIME:  42s

# %%
plot_graph()

# %%
evaluate(model, test_data, print_accu=True)
# Out:
# VALIDATE ACCURACY: 54.76%
