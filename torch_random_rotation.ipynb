# %%
import torch
from torchvision import transforms
from efficientnet_pytorch import EfficientNet
from implementation.utils import *

# %% [markdown]
# ### EfficientNet B0 w/ Random Rotation

# %%
tsfm = [transforms.RandomRotation(degrees=15),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),]

train_data, val_data, test_data = get_dataset(tsfm)

model = EfficientNet.from_name("efficientnet-b0", override_params={'num_classes': 101})
epochs = 30
batch_size = 128

# %%
# GPU usage: 13533MiB 
train(model, train_data, val_data, epochs, batch_size)
# Out:
# EPOCH:  0, TRAIN_LOSS: 3.80886, VAL_ACCU: 0.0904, EXE TIME:  43s
# EPOCH:  1, TRAIN_LOSS: 3.05314, VAL_ACCU: 0.0904, EXE TIME:  43s
# EPOCH:  2, TRAIN_LOSS: 2.76977, VAL_ACCU: 0.0904, EXE TIME:  42s
# EPOCH:  3, TRAIN_LOSS: 3.21297, VAL_ACCU: 0.0086, EXE TIME:  42s
# EPOCH:  4, TRAIN_LOSS: 2.34329, VAL_ACCU: 0.0081, EXE TIME:  43s
# EPOCH:  5, TRAIN_LOSS: 1.96499, VAL_ACCU: 0.0081, EXE TIME:  43s
# EPOCH:  6, TRAIN_LOSS: 1.65146, VAL_ACCU: 0.0081, EXE TIME:  43s
# EPOCH:  7, TRAIN_LOSS: 1.63645, VAL_ACCU: 0.0092, EXE TIME:  43s
# EPOCH:  8, TRAIN_LOSS: 0.99864, VAL_ACCU: 0.0225, EXE TIME:  43s
# EPOCH:  9, TRAIN_LOSS: 1.51836, VAL_ACCU: 0.1717, EXE TIME:  43s
# EPOCH: 10, TRAIN_LOSS: 1.11632, VAL_ACCU: 0.4153, EXE TIME:  43s
# EPOCH: 11, TRAIN_LOSS: 1.19044, VAL_ACCU: 0.5634, EXE TIME:  43s
# EPOCH: 12, TRAIN_LOSS: 0.84070, VAL_ACCU: 0.5755, EXE TIME:  43s
# EPOCH: 13, TRAIN_LOSS: 0.93276, VAL_ACCU: 0.5812, EXE TIME:  43s
# EPOCH: 14, TRAIN_LOSS: 0.65379, VAL_ACCU: 0.6192, EXE TIME:  43s
# EPOCH: 15, TRAIN_LOSS: 0.50256, VAL_ACCU: 0.6313, EXE TIME:  43s
# EPOCH: 16, TRAIN_LOSS: 0.30865, VAL_ACCU: 0.6037, EXE TIME:  43s
# EPOCH: 17, TRAIN_LOSS: 0.39789, VAL_ACCU: 0.6181, EXE TIME:  43s
# EPOCH: 18, TRAIN_LOSS: 0.34546, VAL_ACCU: 0.6463, EXE TIME:  42s
# EPOCH: 19, TRAIN_LOSS: 0.37481, VAL_ACCU: 0.6573, EXE TIME:  43s
# EPOCH: 20, TRAIN_LOSS: 0.32096, VAL_ACCU: 0.6429, EXE TIME:  43s
# EPOCH: 21, TRAIN_LOSS: 0.24012, VAL_ACCU: 0.6336, EXE TIME:  43s
# EPOCH: 22, TRAIN_LOSS: 0.23300, VAL_ACCU: 0.6671, EXE TIME:  42s
# EPOCH: 23, TRAIN_LOSS: 0.33178, VAL_ACCU: 0.6676, EXE TIME:  43s
# EPOCH: 24, TRAIN_LOSS: 0.19424, VAL_ACCU: 0.6624, EXE TIME:  43s
# EPOCH: 25, TRAIN_LOSS: 0.22830, VAL_ACCU: 0.6619, EXE TIME:  43s
# EPOCH: 26, TRAIN_LOSS: 0.14416, VAL_ACCU: 0.6596, EXE TIME:  43s
# EPOCH: 27, TRAIN_LOSS: 0.10460, VAL_ACCU: 0.6584, EXE TIME:  43s
# EPOCH: 28, TRAIN_LOSS: 0.17230, VAL_ACCU: 0.6267, EXE TIME:  43s
# EPOCH: 29, TRAIN_LOSS: 0.14742, VAL_ACCU: 0.6555, EXE TIME:  43s

# %%
plot_graph()

# %%
evaluate(model, test_data, print_accu=True)
# Out:
# VALIDATE ACCURACY: 65.82%
